# %%
import os
import pandas as pd
import mplfinance as mpf

from drl_investment.data.tdx import unpack_data

# %%
daily = pd.read_csv(os.path.abspath('../../tests/assets/SP500_NOV2019_Hist.csv'),index_col=0,parse_dates=True)
daily.index.name = 'Date'
print(daily.shape)
print(daily.head(3))
print(daily.tail(3))
mpf.plot(daily, type='candle')
# Out:
# (20, 5)
#                Open     High      Low    Close     Volume
# Date
# 2019-11-01  3050.72  3066.95  3050.72  3066.91  510301237
# 2019-11-04  3078.96  3085.20  3074.87  3078.27  524848878
# 2019-11-05  3080.80  3083.95  3072.15  3074.62  585634570
#                Open     High      Low    Close     Volume
# Date
# 2019-11-26  3134.85  3142.69  3131.00  3140.52  986041660
# 2019-11-27  3145.49  3154.26  3143.41  3153.63  421853938
# 2019-11-29  3147.18  3150.30  3139.34  3140.98  286602291

# %%
daily = unpack_data(os.path.abspath('../../tests/assets/sh000001.day'))
# daily = daily.tail(100)
print(daily.shape)
print(daily.head(3))
print(daily.tail(3))
mpf.plot(daily, type='candle')
# Out:
# (7886, 6)
#                   open        high         low       close    amount  volume
# 1990-12-19   96.050003   99.980003   95.790001   99.980003  494000.0  1260.0
# 1990-12-20  104.300003  104.389999   99.980003  104.389999   84000.0   197.0
# 1990-12-21  109.070000  109.129997  103.730003  109.129997   16000.0    28.0
#                    open         high          low        close        amount
# 2023-03-28  3256.600098  3264.100098  3241.739990  3245.379883  3.968829e+11  \
# 2023-03-29  3253.620117  3254.560059  3229.580078  3240.060059  4.055428e+11
# 2023-03-30  3243.070068  3263.739990  3220.979980  3261.250000  4.016343e+11
#
#                  volume
# 2023-03-28  295682656.0
# 2023-03-29  296900512.0
# 2023-03-30  299898304.0
# e:\miniconda3\envs\ray\lib\site-packages\mplfinance\_arg_validators.py:83: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
